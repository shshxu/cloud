# %%
import urllib
import lxml.html as lh
import pandas as pd
from bs4 import BeautifulSoup
from distutils.version import LooseVersion
from artifactory import ArtifactoryPath
path = ArtifactoryPath("https://aac-srv-artifactory.nuance.com/webapp/#/artifacts/browse/tree/General/tts-release/com/nuance/vocalizer/voice_operating_points/dun/dun_claire-ml_embedded-high")
for p in path:
    print(p)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-d5aeaa754265> in <module>
#       4 from bs4 import BeautifulSoup
#       5 from distutils.version import LooseVersion
# ----> 6 from artifactory import ArtifactoryPath
#       7 path = ArtifactoryPath("https://aac-srv-artifactory.nuance.com/webapp/#/artifacts/browse/tree/General/tts-release/com/nuance/vocalizer/voice_operating_points/dun/dun_claire-ml_embedded-high")
#       8 for p in path:
#
# ModuleNotFoundError: No module named 'artifactory'

# %%
import lxml.html
url = 'https://aac-srv-artifactory.nuance.com/webapp/#/artifacts/browse/tree/ViewSource/tts-snapshot/com/nuance/vocalizer/voice_operating_points/eng/eng_serena_embedded-high/1.1.2-SNAPSHOT/eng_serena_embedded-high-1.1.2-20190124.084858-1.zip!/metadata.json'
mysite = urllib.request.urlopen(url).read()
lxml_mysite = lxml.html.fromstring(mysite)
print(lxml_mysite.xpath("//tr"))
# Out:
# []

# %%
html = urllib.request.urlopen(url).read()
print(html)
# Out:
# b'\n<!DOCTYPE html>\n<html lang="en">\n\t<head>\n\t\t<meta http-equiv="X-UA-Compatible" content="IE=edge;" charset="utf-8"/>\n\t\t<link rel="icon" href="/vocaholic_static/img/logo_black.png">\n\t\t<title>Vocaholic</title>\n        <script type="text/javascript" src="/vocaholic_static/js/jquery-latest.js?ver=2.2.0"></script>\n        <script type="text/javascript" src="/vocaholic_static/js/bootstrap.min.js?ver=3.3.5"></script>\n        <link href="/vocaholic_static/css/bootstrap.min.css?ver=3.3.5" rel="stylesheet">\n        <script type="text/javascript" src="/vocaholic_static/js/ie10-viewport-bug-workaround.js?ver=1.0.0"></script>\n\t\t<script type="text/javascript" src="/vocaholic_static/js/ajaxcall.js?ver=1.0.0&project=vocaholic"></script>\n        <script type="text/javascript" src="/vocaholic_static/js/jquery.tablesorter.js?ver=2.0.0"></script>\n\t\t<script type="text/javascript" src="/vocaholic_static/js/clipboard.min.js?ver=1.5.12"></script>\n\t\t<script type="text/javascript" 
# ...

# %%
page = requests.get(url)
#Store the contents of the website under doc
doc = lh.fromstring(page.content)
#Parse data that are stored between <tr>..</tr> of HTML
tr_elements = doc.xpath('//td')

# %%
print([len(T) for T in tr_elements[:20]])
# Out:
# [0, 1, 1, 0, 1, 1]

# %%
html = page.text
soup = BeautifulSoup(html)
table = soup.find('table', attrs={'class':"table table-hover tablesorter"})
table_body = table.find('tbody')
rows = table_body.find_all('tr')

# %%
for row in rows:
    cols = row.find_all('td')
    print('a')
